# %% [markdown]
# <a href="https://colab.research.google.com/github/jcdevaney/gawayneLessons/blob/main/week1/Intro%20to%20Audio%20in%20Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Import libraries and give them abbreviations

# %%
import numpy as np
import librosa
import librosa.display
import matplotlib.pyplot as plt

# %% [markdown]
# Import Github repo files

# %%
# !git clone https://github.com/jcdevaney/gawayneLessons.git
# Out:
# Cloning into 'gawayneLessons'...
# remote: Enumerating objects: 85, done.
# remote: Counting objects: 100% (85/85), done.
# remote: Compressing objects: 100% (66/66), done.
# remote: Total 85 (delta 17), reused 82 (delta 17), pack-reused 0
# Receiving objects: 100% (85/85), 25.59 MiB | 18.31 MiB/s, done.
# Resolving deltas: 100% (17/17), done.

# %% [markdown]
# Open entire piano audio file as mono and store the original sampling frequency in a variable

# %%
file = '/content/gawayneLessons/files/r0.wav'
sig , sr = librosa.load(file,mono=True,sr=None)

# %% [markdown]
# Calculate the length in seconds

# %%
length_s = sig.shape[0] / sr
print(length_s)
# Out:
# 20.746530612244896

# %% [markdown]
# Plot signal

# %%
plt.plot(sig)

# %% [markdown]
# Plot x2 with respect to time

# %%
time=np.arange(0,sig.shape[0])/sr

# %%
plt.plot(time,sig)

# %% [markdown]
# Scale x2 and replot with labels

# %%
sig.shape
# Out:
# (914922,)

# %%
max(abs(sig))
# Out:
# 0.71658325

# %%
excursion=max(abs(sig))
sigNew = sig / excursion

# %%
max(abs(sigNew))
# Out:
# 1.0

# %%
plt.plot(time,sigNew)
plt.xlabel('Time (s)')
plt.ylabel('Amplitude')
plt.title('r0 Waveform')
# Out:
# Text(0.5, 1.0, 'r0 Waveform')

# %%
plt.plot(time,sigNew)
plt.xlabel('Time (s)')
plt.ylabel('Amplitude')
plt.title('r0 Waveform')
plt.xlim(0,1)
plt.ylim(-.18,.18)
# Out:
# (-0.18, 0.18)

# %% [markdown]
# Plot only a segment of signal (instead of just zooming in)

# %%
plt.plot(time[1:44100],sigNew[1:44100])
plt.xlabel('Time (s)')
plt.ylabel('Amplitude')
plt.title('r0 Waveform')
# Out:
# Text(0.5, 1.0, 'r0 Waveform')

# %% [markdown]
# Load and plot violin and voice audio files

# %%
violinFile = '/content/gawayneLessons/files/h.wav'
voiceFile = '/content/gawayneLessons/files/mc.wav'

violinSig , sr2 = librosa.load(violinFile,mono=True,sr=None)
voiceSig , sr3 = librosa.load(voiceFile,mono=True,sr=None)

timeViolin=np.arange(0,violinSig.shape[0])/sr2
timeVoice=np.arange(0,voiceSig.shape[0])/sr3

# %% [markdown]
# Plot time-domain signal before resampling

# %%
plt.plot(timeViolin,violinSig)
plt.xlabel('Time (s)')
plt.ylabel('Amplitude')
plt.title('Violin Waveform')
# Out:
# Text(0.5, 1.0, 'Violin Waveform')

# %%
plt.plot(timeVoice,voiceSig)
plt.xlabel('Time (s)')
plt.ylabel('Amplitude')
plt.title('Voice Waveform')
# Out:
# Text(0.5, 1.0, 'Voice Waveform')

# %% [markdown]
# Plot linear spectrograms

# %%
violinSpec = librosa.amplitude_to_db(np.abs(librosa.stft(violinSig)), ref=np.max)

# %%
librosa.display.specshow(violinSpec, y_axis='linear')
plt.colorbar(format='%+2.0f dB')
plt.title('Violin: Linear-frequency power spectrogram')
# Out:
# Text(0.5, 1.0, 'Violin: Linear-frequency power spectrogram')

# %%
vocalSpec = librosa.amplitude_to_db(np.abs(librosa.stft(voiceSig)), ref=np.max)

# %%
librosa.display.specshow(vocalSpec, y_axis='linear')
plt.colorbar(format='%+2.0f dB')
plt.title('Vocal: Linear-frequency power spectrogram')
# Out:
# Text(0.5, 1.0, 'Vocal: Linear-frequency power spectrogram')

# %% [markdown]
# Plot logarithmic spectrograms

# %%
librosa.display.specshow(violinSpec, y_axis='log')
plt.colorbar(format='%+2.0f dB')
plt.title('Violin: Log-frequency power spectrogram')
# Out:
# Text(0.5, 1.0, 'Violin: Log-frequency power spectrogram')

# %%
librosa.display.specshow(vocalSpec, y_axis='log')
plt.colorbar(format='%+2.0f dB')
plt.title('Vocal: Log-frequency power spectrogram')
# Out:
# Text(0.5, 1.0, 'Vocal: Log-frequency power spectrogram')
